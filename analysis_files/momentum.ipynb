# %% [markdown]
# # Momentum Analysis
# - Designed to figure out if the hypothetical "momentum" is real
# - Looks at going into games from a win, going into games from a loss
# - Chance of winning as the game moves on
# - How teams perform based on another team having "momentum"
# - An exact definition of "momentum" in baseball
